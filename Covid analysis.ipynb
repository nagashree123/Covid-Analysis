# %%
pip install covid
# Out:
# ...
#
# ...

# %%
 import covid

# %%
from covid import Covid
import pprint
covid = Covid()
world_covid_data = covid19.get_data()
pprint.pprint(world_covid_data)
# Out:
# [{'active': None,
#   'confirmed': 33218607,
#   'country': 'US',
#   'deaths': 593293,
#   'id': '180',
#   'last_update': 1622204470000,
#   'latitude': 40.0,
#   'longitude': -100.0,
#   'recovered': None},
#  {'active': 2343152,
#   'confirmed': 27555457,
#   'country': 'India',
#   'deaths': 318895,
#   'id': '80',
#   'last_update': 1622204470000,
#   'latitude': 20.593684,
#   'longitude': 78.96288,
#   'recovered': 24893410},
#  {'active': 1429678,
#   'confirmed': 16342162,
#   'country': 'Brazil',
#   'deaths': 456674,
#   'id': '24',
#   'last_update': 1622204470000,
#   'latitude': -14.235,
#   'longitude': -51.9253,
#   'recovered': 14455810},
#  {'active': 5198644,
#   'confirmed': 5697081,
#   'country': 'France',
#   'deaths': 109327,
#   'id': '63',
#   'last_update': 1622204470000,
#   'latitude': 46.2276,
#   'longitude': 2.2137,
#   'recovered': 389110},
#  {'active': 102764,
#   'confirmed': 5220549,
#   'country': 'Turkey',
#   'deaths': 46970,
#   'id': '179',
# ...

# %%
from covid import Covid
covid=Covid()
active=covid19.get_total_active_cases()
confirmed=covid19.get_total_confirmed_cases()
recovered=covid19.get_total_recovered()
deaths=covid19.get_total_deaths()
print('Global covid status:')
print('active cases:',active)
print('recovered cases:',recovered)
print('deaths:',deaths)
# Out:
# Global covid status:
# active cases: 26747228
# recovered cases: 106163854
# deaths: 3513137

# %%
from covid import Covid
import pprint
covid=Covid()
covid_Brazil=covid19.get_status_by_country_name('Brazil')
print('Covid Brazil:')
pprint.pprint(covid_Brazil)
# Out:
# Covid Brazil:
# {'active': 1429678,
#  'confirmed': 16342162,
#  'country': 'Brazil',
#  'deaths': 456674,
#  'id': '24',
#  'last_update': 1622204470000,
#  'latitude': -14.235,
#  'longitude': -51.9253,
#  'recovered': 14455810}

# %%
from covid import Covid
import pprint
covid=Covid()
covid_US=covid19.get_status_by_country_name('US')
print('Covid US:')
pprint.pprint(covid_US)
# Out:
# Covid US:
# {'active': None,
#  'confirmed': 33218607,
#  'country': 'US',
#  'deaths': 593293,
#  'id': '180',
#  'last_update': 1622204470000,
#  'latitude': 40.0,
#  'longitude': -100.0,
#  'recovered': None}
